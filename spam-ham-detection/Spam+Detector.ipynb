# %% [markdown]
# ### SPAM Ham Detection

# %%
import random
import nltk
import pandas as pd
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer

# %%
## Reading the given dataset
spam = pd.read_csv("https://cdn.upgrad.com/UpGrad/temp/bab3e784-e601-4911-9000-f1fbc994a62d/SMSSpamCollection.txt",  sep='\t', names=["label", "message"])

# %%
print(spam.head())
# Out:
#   label                                            message
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
## Converting the read dataset in to a list of tuples, each tuple(row) contianing the message and it's label
data_set = []
for index,row in spam.iterrows():
    data_set.append((row['message'], row['label']))

# %%
print(data_set[:5])
# Out:
# [('Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...', 'ham'), ('Ok lar... Joking wif u oni...', 'ham'), ("Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's", 'spam'), ('U dun say so early hor... U c already then say...', 'ham'), ("Nah I don't think he goes to usf, he lives around here though", 'ham')]

# %%
print(len(data_set))
# Out:
# 5572

# %% [markdown]
# ### Preprocessing

# %%
## initialise the inbuilt Stemmer and the Lemmatizer
stemmer = PorterStemmer()
wordnet_lemmatizer = WordNetLemmatizer()

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')

def preprocess(document, stem=True):
    'changes document to lower case, removes stopwords and lemmatizes/stems the remainder of the sentence'

    # change sentence to lower case
    document = document.lower()

    # tokenize into words
    words = word_tokenize(document)

    # remove stop words
    words = [word for word in words if word not in stopwords.words("english")]

    if stem:
        words = [stemmer.stem(word) for word in words]
    else:
        words = [wordnet_lemmatizer.lemmatize(word, pos='v') for word in words]

    # join words to make sentence
    document = " ".join(words)

    return document
# Out:
# [nltk_data] Downloading package punkt to /home/simplify/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/simplify/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
## - Performing the preprocessing steps on all messages
messages_set = []
for (message, label) in data_set:
    words_filtered = [e.lower() for e in preprocess(message, stem=True).split() if len(e) >= 3]
    messages_set.append((words_filtered, label))

# %%
print(messages_set[:5])
# Out:
# [(['jurong', 'point', 'crazi', 'avail', 'bugi', 'great', 'world', 'buffet', '...', 'cine', 'got', 'amor', 'wat', '...'], 'ham'), (['lar', '...', 'joke', 'wif', 'oni', '...'], 'ham'), (['free', 'entri', 'wkli', 'comp', 'win', 'cup', 'final', 'tkt', '21st', 'may', '2005.', 'text', '87121', 'receiv', 'entri', 'question', 'std', 'txt', 'rate', 'appli', '08452810075over18'], 'spam'), (['dun', 'say', 'earli', 'hor', '...', 'alreadi', 'say', '...'], 'ham'), (['nah', "n't", 'think', 'goe', 'usf', 'live', 'around', 'though'], 'ham')]

# %% [markdown]
# ### Preparing to create features

# %%
## - creating a single list of all words in the entire dataset for feature list creation

def get_words_in_messages(messages):
    all_words = []
    for (message, label) in messages:
      all_words.extend(message)
    return all_words

# %%
## - creating a final feature list using an intuitive FreqDist, to eliminate all the duplicate words
## Note : we can use the Frequency Distribution of the entire dataset to calculate Tf-Idf scores like we did earlier.

def get_word_features(wordlist):

    #print(wordlist[:10])
    wordlist = nltk.FreqDist(wordlist)
    word_features = wordlist.keys()
    return word_features

# %%
## - creating the word features for the entire dataset
word_features = get_word_features(get_words_in_messages(messages_set))
print(len(word_features))
# Out:
# 7618

# %%
word_features
# Out:
930705', 'deliveri', 'tomorrow', 'hope', 'man', 'well', 'endow', 'inch', 'hep', 'immunis', 'nigeria', 'fair', 'tyler', 'could', 'mayb', 'ask', 'bit', 'stubborn', 'hospit', 'kept', 'weak', 'sucker', 'saw', 'class', 'gram', 'usual', 'run', 'half', 'eighth', 'smarter', 'almost', 'whole', 'second', 'fyi', 'ride', 'morn', 'crash', 'place', 'wow', 'never', 'realiz', 'embarass', 'accomod', 'thought', 'sinc', 'best', 'seem', 'happi', 'cave', 'sorri', 'give', 'offer', 'sptv', 'new', 'jersey', 'devil', 'detroit', 'red', 'wing', 'play', 'ice', 'hockey', 'correct', 'incorrect', 'end', 'mallika', 'sherawat', 'yesterday', 'find', 'url', 'congrat', 'year', 'special', 'cinema', 'pass', '09061209465', 'suprman', 'matrix3', 'starwars3', 'etc', 'bx420-ip4-5w', '150pm', 'later', 'reach', 'gauti', 'sehwag', 'odi', 'seri', 'pick', 'burger', 'move', 'pain', 'kill', 'good', 'girl', 'situat', 'seeker', 'part', 'check', 'took', 'forev', 'come', 'doubl', 'hair', 'dresser', 'said', 'wun', 'cut', 'short', 'nice', 'advis', 'follow', 'recent', 'review', 'mob', 'award', '£1500', 'bonu', '09066364589', 'song', 'dedic', 'day', 'valuabl', 'frnd', 'rpli ...

# %% [markdown]
# ### Preparing to create a train and test set

# %%
## - creating slicing index at 80% threshold
sliceIndex = int((len(messages_set)*.8))

# %%
## - shuffle the pack to create a random and unbiased split of the dataset
random.shuffle(messages_set)

# %%
train_messages, test_messages = messages_set[:sliceIndex], messages_set[sliceIndex:]

# %%
len(train_messages)
len(test_messages)
# Out:
# 1115

# %% [markdown]
# ### Preparing to create feature maps for train and test data

# %%
## creating a LazyMap of feature presence for each of the 8K+ features with respect to each of the SMS messages
def extract_features(document):
    document_words = set(document)
    features = {}
    for word in word_features:
        features['contains(%s)' % word] = (word in document_words)
    return features

# %%
## - creating the feature map of train and test data

training_set = nltk.classify.apply_features(extract_features, train_messages)
testing_set = nltk.classify.apply_features(extract_features, test_messages)

# %%
print(training_set[:5])
# Out:
# [({'contains(jurong)': False, 'contains(point)': False, 'contains(crazi)': False, 'contains(avail)': False, 'contains(bugi)': False, 'contains(great)': False, 'contains(world)': False, 'contains(buffet)': False, 'contains(...)': False, 'contains(cine)': False, 'contains(got)': False, 'contains(amor)': False, 'contains(wat)': False, 'contains(lar)': False, 'contains(joke)': False, 'contains(wif)': False, 'contains(oni)': False, 'contains(free)': False, 'contains(entri)': False, 'contains(wkli)': False, 'contains(comp)': False, 'contains(win)': False, 'contains(cup)': False, 'contains(final)': False, 'contains(tkt)': False, 'contains(21st)': False, 'contains(may)': False, 'contains(2005.)': False, 'contains(text)': False, 'contains(87121)': False, 'contains(receiv)': False, 'contains(question)': False, 'contains(std)': False, 'contains(txt)': False, 'contains(rate)': True, 'contains(appli)': False, 'contains(08452810075over18)': False, 'contains(dun)': False, 'contains(say)': False, 'contains(earli)': False, 'contains(hor)': False, 'contains(alreadi)': False, 'contains(nah)': False, "contains(n't)": False, 'contains(think)': False, 'contains(goe)': False, 'contains(usf)': False, 'contains(live)': False, 'contains(around)': False, 'contains(though)': False, 'contains(freemsg)': False, 'contains(hey)': False, 'contains(darl)': False, 'contains(week)': False, 'contains(word)': False, 'contains(back)': False, 'contains(like)': False, 'contains(fun)': False, 'contains(still)': False, 'contains(xxx)': False, 'contains(chg)': False, 'contains(send)': False, 'contains(£1.50)': False, 'contains(rcv)': False, 'contains(even)': False, 'contains(brother)': False, 'contains(speak)': False, 'contains(treat)': False, 'contains(aid)': False, 'contains(patent)': False, 'contains(per)': True, 'contains(request)': False, "contains('mell)": False, 'contains(mell)': False, 'contains(oru)': False, 'contains(minnaminungint)': False, 'contains(nurungu)': False, 'contains(vettam)': False, 'contains(set)': False, 'contains(callertun)': False, 'contains(caller)': False, 'contains(press)': False, 'contains(copi)': False, 'contains(friend)': False, 'contains(winner)': False, 'contains(valu)': False, 'contains(network)': False, 'contains(custom)': False, 'contains(select)': False, 'contains(receivea)': False, 'contains(£900)': False, 'contains(prize)': False, 'contains(reward)': False, 'contains(claim)': False, 'contains(call)': True, 'contains(09061701461.)': False, 'contains(code)': False, 'contains(kl341)': False, 'contains(valid)': False, 'contains(hour)': False, 'contains(mobil)': False, 'contains(month)': False, 'contains(entitl)': False, 'contains(updat)': False, 'contains(latest)': False, 'contains(colour)': False, 'contains(camera)': False, 'contains(08002986030)': False, 'contains(gon)': False, 'contains(home)': False, 'contains(soon)': False, 'contains(want)': False, 'contains(talk)': False, 'contains(stuff)': False, 'contains(anymor)': False, 'contains(tonight)': False, "contains('ve)": False, 'contains(cri)': False, 'contains(enough)': False, 'contains(today)': False, 'contains(six)': False, 'contains(chanc)': True, 'contains(cash)': False, 'contains(100)': False, 'contains(20,000)': False, 'contains(pound)': False, 'contains(csh11)': False, 'contains(87575.)': False, 'contains(cost)': False, 'contains(150p/day)': False, 'contains(6day)': False, 'contains(16+)': False, 'contains(tsandc)': False, 'contains(repli)': False, 'contains(info)': False, 'contains(urgent)': False, 'contains(membership)': False, 'contains(£100,000)': False, 'contains(jackpot)': False, 'contains(81010)': False, 'contains(www.dbuk.net)': False, 'contains(lccltd)': False, 'contains(pobox)': False, 'contains(4403ldnw1a7rw18)': False, 'contains(search)': False, 'contains(right)': False, 'contains(thank)': False, 'contains(breather)': False, 'contains(promis)': False, 'contains(wont)': False, 'contains(take)': False, 'contains(help)': False, 'contains(grant)': False, 'contains( ...

# %%
print('Training set size : ', len(training_set))
print('Test set size : ', len(testing_set))
# Out:
# Training set size :  4457
# Test set size :  1115

# %% [markdown]
# ### Training

# %%
## Training the classifier with NaiveBayes algorithm
spamClassifier = nltk.NaiveBayesClassifier.train(training_set)

# %% [markdown]
# ### Evaluation

# %%
## - Analyzing the accuracy of the test set
print(nltk.classify.accuracy(spamClassifier, training_set))
# Out:
# 0.9937177473636976

# %%
## Analyzing the accuracy of the test set
print(nltk.classify.accuracy(spamClassifier, testing_set))
# Out:
# 0.9757847533632287

# %%
## Testing a example message with our newly trained classifier
m = 'CONGRATULATIONS!! As a valued account holder you have been selected to receive a £900 prize reward! Valid 12 hours only.'
print('Classification result : ', spamClassifier.classify(extract_features(m.split())))
# Out:
# Classification result :  spam

# %%
## Priting the most informative features in the classifier
print(spamClassifier.show_most_informative_features(50))
# Out:
# Most Informative Features
#          contains(award) = True             spam : ham    =    200.5 : 1.0
#           contains(code) = True             spam : ham    =    114.3 : 1.0
#          contains(nokia) = True             spam : ham    =    104.8 : 1.0
#          contains(await) = True             spam : ham    =     88.4 : 1.0
#         contains(servic) = True             spam : ham    =     84.1 : 1.0
#        contains(attempt) = True             spam : ham    =     75.5 : 1.0
#          contains(expir) = True             spam : ham    =     75.5 : 1.0
#            contains(txt) = True             spam : ham    =     71.7 : 1.0
#         contains(urgent) = True             spam : ham    =     69.7 : 1.0
#        contains(landlin) = True             spam : ham    =     68.6 : 1.0
#       contains(deliveri) = True             spam : ham    =     66.8 : 1.0
#         contains(privat) = True             spam : ham    =     66.8 : 1.0
#          contains(mobil) = True             spam : ham    =     62.3 : 1.0
#          contains(orang) = True             spam : ham    =     60.8 : 1.0
#            contains(100) = True             spam : ham    =     58.2 : 1.0
#         contains(camera) = True             spam : ham    =     58.2 : 1.0
#           contains(club) = True             spam : ham    =     58.2 : 1.0
#            contains(opt) = True             spam : ham    =     58.2 : 1.0
#         contains(reveal) = True             spam : ham    =     58.2 : 1.0
#      contains(congratul) = True             spam : ham    =     53.9 : 1.0
#           contains(oper) = True             spam : ham    =     53.9 : 1.0
#         contains(latest) = True             spam : ham    =     47.1 : 1.0
#          contains(appli) = True             spam : ham    =     45.3 : 1.0
#           contains(rate) = True             spam : ham    =     45.3 : 1.0
#        contains(auction) = True             spam : ham    =     45.3 : 1.0
#           contains(draw) = True             spam : ham    =     42.4 : 1.0
#          contains(pound) = True             spam : ham    =     41.6 : 1.0
#       contains(motorola) = True             spam : ham    =     41.0 : 1.0
#        contains(collect) = True             spam : ham    =     39.3 : 1.0
#      contains(statement) = True             spam : ham    =     37.5 : 1.0
#           contains(comp) = True             spam : ham    =     36.7 : 1.0
#            contains(sex) = True             spam : ham    =     36.7 : 1.0
#         contains(txting) = True             spam : ham    =     36.7 : 1.0
#           contains(info) = True             spam : ham    =     34.9 : 1.0
#           contains(land) = True             spam : ham    =     34.9 : 1.0
#         contains(select) = True             spam : ham    =     33.8 : 1.0
#        contains(england) = True             spam : ham    =     32.3 : 1.0
#        contains(sunshin) = True             spam : ham    =     32.3 : 1.0
#           contains(user) = True             spam : ham    =     32.3 : 1.0
#         contains(custom) = True             spam : ham    =     32.3 : 1.0
#            contains(box) = True             spam : ham    =     31.2 : 1.0
#         contains(receiv) = True             spam : ham    =     28.4 : 1.0
#           contains(1000) = True             spam : ham    =     28.0 : 1.0
#           contains(cash) = True             spam : ham    =     28.0 : 1.0
#            contains(del) = True             spam : ham    =     28.0 : 1.0
#        contains(fantast) = True             spam : ham    =     28.0 : 1.0
#         contains(reward) = True             spam : ham    =     28.0 : 1.0
#            contains(win) = True             spam : ham    =     27.2 : 1.0
#          contains(offer) = True             spam : ham    =     26.3 : 1.0
#            contains(per) = True             spam : ham    =     26.2 : 1.0
# None

# %%
## storing the classifier on disk for later usage
import pickle
f = open('nb_spam_classifier.pickle', 'wb')
pickle.dump(spamClassifier,f)
print('Classifier stored at ', f.name)
f.close()
# Out:
# Classifier stored at  nb_spam_classifier.pickle
